# %% [markdown]
# CSE 431 - Term Project
#
# Student Name: Merve Adali
# Student No: 211805049
# Instructor: Assoc. Prof. Dr. Fatih Soygazi
#
# General Comments:
# This project implements a Turkish smart home command recognition system using Word2Vec embeddings, cosine similarity, and TF-IDF weighted sentence representations.

# %%
# !python src/0_load_commands.py
# Out:
# Excel path: C:\Users\msı\OneDrive - Aydin Adnan Menderes University\Masaüstü\smart_home_nlp\data\TR_Commands.xlsx
# Total command: 71
# ['ışığı aç', 'ışığı yak', 'ışığı söndür', 'ışığı kapa', 'ışığı arttır', 'ışığı kıs', 'ışığı azalt', 'parlaklığı arttır', 'parlaklığı azalt', 'aydınlatmayı arttır']

# %%
# !python src/1_prepare_dataset.py
# Out:
# Excel path: C:\Users\msı\OneDrive - Aydin Adnan Menderes University\Masaüstü\smart_home_nlp\data\TR_Commands.xlsx
# train_commands.txt has been successfully created
# Total number of samples: 71

# %%
# !python src/2_finetune_word2vec.py
# Out:
# Total training sentences: 71
# Pretrained vectors loaded.
# Number of common words: 54
# Fine-tuned Word2Vec model saved successfully.

# %%
# !python src/3_finetune_word2vec_ngrams.py
# Out:
# Example bigram sentence: ['ışığı', 'aç']
# Common unigram words: 52
# Bigram Word2Vec model saved successfully.

# %%
# !python src/4_sentence_embeddings.py
# Out:
# Embeddings saved for unigram
# Embeddings saved for bigram

# %%
# !python src/5_evaluation.py
# Out:
#  UNIGRAM RESULTS
# MEAN    Precision=0.82 Recall=0.90 F1=0.86
# TF-IDF  Precision=0.82 Recall=0.90 F1=0.86
#
#  BIGRAM RESULTS
# MEAN    Precision=0.82 Recall=0.90 F1=0.86
# TF-IDF  Precision=0.82 Recall=0.90 F1=0.86
